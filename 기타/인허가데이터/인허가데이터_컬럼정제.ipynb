# %%
import os
import openpyxl

file_list = os.listdir()
file_list
# Out:
# ['.ipynb_checkpoints',
#  '6410000_경기도_01_01_01_P_병원.csv',
#  '6410000_경기도_01_01_02_P_의원.csv',
#  '6410000_경기도_01_01_03_P_부속의료기관.csv',
#  '6410000_경기도_01_01_04_P_산후조리업.csv',
#  '6410000_경기도_01_01_05_P_안전상비의약품판매업소.csv',
#  '6410000_경기도_01_01_06_P_약국.csv',
#  '6410000_경기도_01_01_07_P_응급환자이송업.csv',
#  '6410000_경기도_01_01_08_P_의료법인.csv',
#  '6410000_경기도_01_01_10_P_의료유사업.csv',
#  '6410000_경기도_01_02_01_P_안경업.csv',
#  '6410000_경기도_01_02_02_P_의료기기수리업.csv',
#  '6410000_경기도_01_02_03_P_의료기기판매임대업.csv',
#  '6410000_경기도_01_02_04_P_치과기공소.csv',
#  '6410000_경기도_02_03_01_P_동물병원.csv',
#  '6410000_경기도_02_03_02_P_동물약국.csv',
#  '6410000_경기도_02_03_03_P_동물용의료용구판매업.csv',
#  '6410000_경기도_02_03_04_P_동물용의약품도매상.csv',
#  '6410000_경기도_02_03_05_P_동물장묘업.csv',
#  '6410000_경기도_02_03_06_P_동물생산업.csv',
#  '6410000_경기도_02_03_07_P_동물판매업.csv',
#  '6410000_경기도_02_03_08_P_동물수입업.csv',
#  '6410000_경기도_02_03_09_P_동물전시업.csv',
#  '6410000_경기도_02_03_10_P_동물위탁관리업.csv',
#  '6410000_경기도_02_03_11_P_동물미용업.csv',
# ...

# %%
csv_list=[]
for a in file_list:
    if a[-4:] ==".csv":
        if(a[-8:-4]!="수정완료"):
            csv_list.append(a)

# %%
csv_list
# Out:
# ['6410000_경기도_01_01_01_P_병원.csv',
#  '6410000_경기도_01_01_02_P_의원.csv',
#  '6410000_경기도_01_01_03_P_부속의료기관.csv',
#  '6410000_경기도_01_01_04_P_산후조리업.csv',
#  '6410000_경기도_01_01_05_P_안전상비의약품판매업소.csv',
#  '6410000_경기도_01_01_06_P_약국.csv',
#  '6410000_경기도_01_01_07_P_응급환자이송업.csv',
#  '6410000_경기도_01_01_08_P_의료법인.csv',
#  '6410000_경기도_01_01_10_P_의료유사업.csv',
#  '6410000_경기도_01_02_01_P_안경업.csv',
#  '6410000_경기도_01_02_02_P_의료기기수리업.csv',
#  '6410000_경기도_01_02_03_P_의료기기판매임대업.csv',
#  '6410000_경기도_01_02_04_P_치과기공소.csv',
#  '6410000_경기도_02_03_01_P_동물병원.csv',
#  '6410000_경기도_02_03_02_P_동물약국.csv',
#  '6410000_경기도_02_03_03_P_동물용의료용구판매업.csv',
#  '6410000_경기도_02_03_04_P_동물용의약품도매상.csv',
#  '6410000_경기도_02_03_05_P_동물장묘업.csv',
#  '6410000_경기도_02_03_06_P_동물생산업.csv',
#  '6410000_경기도_02_03_07_P_동물판매업.csv',
#  '6410000_경기도_02_03_08_P_동물수입업.csv',
#  '6410000_경기도_02_03_09_P_동물전시업.csv',
#  '6410000_경기도_02_03_10_P_동물위탁관리업.csv',
#  '6410000_경기도_02_03_11_P_동물미용업.csv',
#  '6410000_경기도_02_03_12_P_동물운송업.csv',
# ...

# %%
import pandas as pd

# %%
columns_nm = ['개방서비스명', '개방서비스아이디','관리번호', '인허가일자', '인허가취소일자', '영업상태구분코드',
       '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
       '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호', '사업장명', '업태구분명', '좌표정보(x)',
       '좌표정보(y)']

# %%
df=pd.read_csv(csv_list[0],encoding='cp949')

# %%
df=pd.read_csv(csv_list[0],encoding='cp949')
df['인허가일자']=df['인허가일자'].astype('str')
df['인허가일자']= df['인허가일자'].str.slice(start=0,stop=4)
df['업력'] = 2022 - pd.to_numeric(df['인허가일자'])

# %%
df
# Out:
#         번호 개방서비스명    개방서비스아이디  개방자치단체코드                       관리번호 인허가일자  \
# 0        1     병원  01_01_01_P   3740000  PHMA219983740031021200001  1998
# 1        2     병원  01_01_01_P   3740000  PHMA219993740031021200002  1999
# 2        3     병원  01_01_01_P   3740000  PHMA220073740033021200001  2007
# 3        4     병원  01_01_01_P   3740000  PHMA220073740106021200001  2007
# 4        5     병원  01_01_01_P   3740000  PHMA220093740031021200001  2009
# ...    ...    ...         ...       ...                        ...   ...
# 1327  1328     병원  01_01_01_P   5700000  PHMA220014110016021200001  2001
# 1328  1329     병원  01_01_01_P   5700000  PHMA219984110016021200001  1998
# 1329  1330     병원  01_01_01_P   5700000  PHMA220195700008021200001  2019
# 1330  1331     병원  01_01_01_P   5700000  PHMA220185700008021200001  2018
# 1331  1332     병원  01_01_01_P   5700000  PHMA220205700008021200001  2020
#
#       인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 완화의료지정형태  완화의료담당부서명  구급차특수  \
# ...

# %%
df
# Out:
#           번호 개방서비스명    개방서비스아이디  개방자치단체코드                       관리번호  \
# 0          1     의원  01_01_02_P   3740000  PHMA120023740031041100014
# 1          2     의원  01_01_02_P   3740000  PHMA119683740033041100002
# 2          3     의원  01_01_02_P   3740000  PHMA120053740106041100022
# 3          4     의원  01_01_02_P   3740000  PHMA120063740032041100202
# 4          5     의원  01_01_02_P   3740000  PHMA120213740032041100026
# ...      ...    ...         ...       ...                        ...
# 23584  23586     의원  01_01_02_P   5700000  PHMA120205700008041100002
# 23585  23587     의원  01_01_02_P   5700000  PHMA120215700008041100001
# 23586  23588     의원  01_01_02_P   5700000  PHMA120185700008041100006
# 23587  23589     의원  01_01_02_P   5700000  PHMA119994110016041100002
# 23588  23590     의원  01_01_02_P   5700000  PHMA120205700008041100003
#
#           인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ...  \
# 0      20020603      NaN         2     휴업         2  ...
# ...

# %%
for a in csv_list:
    df = pd.read_csv(a,encoding='cp949')
    print(a)
    df2 = df[columns_nm]
    df2['인허가년도']=df2['인허가일자'].astype('str')
    df2['인허가년도']= df2['인허가년도'].str.slice(start=0,stop=4)
    df2['업력'] = 2022 - pd.to_numeric(df2['인허가년도'])
    df2.to_csv('수정/'+a[:-4]+"_수정완료"+a[-4:],index=False,encoding="cp949")
# Out:
# 6410000_경기도_01_01_01_P_병원.csv
# 6410000_경기도_01_01_02_P_의원.csv
# C:\Users\user\AppData\Local\Temp\ipykernel_8480\2892505224.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['인허가년도']=df2['인허가일자'].astype('str')
# C:\Users\user\AppData\Local\Temp\ipykernel_8480\2892505224.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['인허가년도']= df2['인허가년도'].str.slice(start=0,stop=4)
# C:\Users\user\AppData\Local\Temp\ipykernel_8480\2892505224.py:7: SettingWithCopyWarning:
# ...

# %%
xlsx_list
# Out:
# []
